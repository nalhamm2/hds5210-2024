# %%
import pandas as pd
import json

# %%
ga = pd.read_excel('ga_hospitals.xlsx')

# %%
ga = ga.set_index('Hospital Name')

# %%
ga
# Out:
#                                                       City  \
# Hospital Name
# COOK MEDICAL CENTER                                   ADEL
# PHOEBE PUTNEY MEMORIAL HOSPITAL                     ALBANY
# PHOEBE PUTNEY MEMORIAL HOSPITAL - NORTH CAMPUS      ALBANY
# BACON COUNTY HOSPITAL                                 ALMA
# PHOEBE SUMTER MEDICAL CENTER                      AMERICUS
# ...                                                    ...
# MAYO CLINIC HEALTH SYSTEM IN WAYCROSS, INC        WAYCROSS
# SATILLA PARK HOSPITAL                             WAYCROSS
# BURKE MEDICAL CENTER                            WAYNESBORO
# WILDWOOD LIFESTYLE CENTER AND HOSPITAL            WILDWOOD
# BARROW MEDICAL CENTER                               WINDER
#
#                                                               TYPE  \
# Hospital Name
# COOK MEDICAL CENTER                             GENERAL ACUTE CARE
# PHOEBE PUTNEY MEMORIAL HOSPITAL                 GENERAL ACUTE CARE
# ...

# %%
ga.to_json('ga_hospitals.json', orient='index', indent=2)
